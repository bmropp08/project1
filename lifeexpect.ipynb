# %%
import pandas as pd
import os
import numpy as np

# %%
data_file = "life_expectancy.csv"
data_file2 = "uszips.csv"
data_file3 = "tax_rates.csv"
life_df = pd.read_csv(data_file)
zips = pd.read_csv(data_file2)
tax_rates = pd.read_csv(data_file3)
zips.head()
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18027 -66.75266   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36075 -67.17541     Aguada       PR  Puerto Rico  True
# 2  603  18.45744 -67.12225  Aguadilla       PR  Puerto Rico  True
# 3  606  18.16585 -66.93716    Maricao       PR  Puerto Rico  True
# 4  610  18.29110 -67.12243     Anasco       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN     17126.0    102.6        72001    Adjuntas
# 1          NaN     37895.0    482.5        72003      Aguada
# 2          NaN     49136.0    552.4        72005   Aguadilla
# 3          NaN      5751.0     50.1        72093     Maricao
# 4          NaN     26153.0    272.1        72011      Añasco
#
#                                       county_weights  \
# 0                    {"72001": 98.73, "72141": 1.27}
# 1                                     {"72003": 100}
# ...

# %%
#cut down zips dataframe to only columns we need "county_name" and "zip"
zips = zips[["county_name", "zip"]]
tax_rates = tax_rates[["ZipCode","EstimatedCombinedRate"]]
#remove blanks from tax_rates dataframe
tax_rates = tax_rates.dropna()
#average tax rates by zip code
#tax_rates = tax_rates.groupby("ZipCode").mean()

#create new column in tax_rates and start at 1 to end of column
merged_df = tax_rates.merge(zips, left_on="ZipCode", right_on="zip")

# %%
merged_df.head()
merged_df = merged_df[["zip","county_name","EstimatedCombinedRate"]]

# %%
data_file = "life_expectancy.csv"
life_df = pd.read_csv(data_file)
#remove data with missing values
life_df = life_df.dropna()
county_df = life_df.groupby("County").mean()


#sort by life expectancy
county_df = county_df.sort_values("Life Expectancy", ascending=False)
#add ranking column starting with 1 to end of dataframe
county_df["Rank"] = range(1, len(county_df) + 1)


#rename rank to "Life Expectancy Rank"
county_df = county_df.rename(columns={"Rank": "Life Expectancy Rank"})
county_df.head()
# Out:
# C:\Users\geoff\AppData\Local\Temp\ipykernel_24692\2657171529.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   county_df = df.groupby("County").mean()
#                      Census Tract Number  Life Expectancy  \
# County
# Cheyenne County, CO               9606.0             89.5
# Wayne County, UT                  9791.0             89.3
# Haskell County, KS                4631.0             88.6
# Stanton County, KS                9641.0             87.9
# Custer County, ID                 9602.0             87.7
#
#                      Life Expectancy Standard Error  Life Expectancy Rank
# County
# Cheyenne County, CO                          2.8702                     1
# Wayne County, UT                             2.6795                     2
# ...
